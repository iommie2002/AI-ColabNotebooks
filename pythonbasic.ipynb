# %%
print("hello world ")
print(783)

# %%
print("Hello I am omkar ")  #this is the python comment

print("my name")  #this is my name
# Out:
# Hello I am omkar
# my name

# %%
a=10
print(a)
a=11
print(a)
# Out:
# 10
# 11

# %%
a="orange"
b="apple"
c="jackfruit"
print(a + b + c)
# Out:
# orangeapplejackfruit

# %%
x="orange"
y="apple"
z="jackfruit"
print(x)
print(y)
print(z)
# Out:
# orange
# apple
# jackfruit

# %%
x,y,z="orange","banana","jackfruit"
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# jackfruit

# %%
a="orange"
 #  print(a)    #space is considered as a character in python
# Out:
#   File "<ipython-input-13-f455633725b9>", line 2
#     print(a)
#     ^
# IndentationError: unexpected indent
#   File "<ipython-input-14-14678005593e>", line 2
#     print(a)    #space is considered as a character in python
#     ^
# IndentationError: unexpected indent

# %%
k=2;
print(k)    #to print the variable
print(type(k))   # to show the type of the variable
f=1.9998   #declaring a floating number
print(f)
print(type(f))
m=3+2j   #assigning a complex number
print(m)
type(m)
n=int(f)  #assigning the integer
print(n)
o=2.333333
p=int(o)
print(p)
# Out:
# 2
# <class 'int'>
# 1.9998
# <class 'float'>
# (3+2j)
# 1
# 2

# %%
a=10
b=23
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(pow(a,b))   #this  is 10 to the power 23
print(pow(b,a))   #23 to the power 10
print(b**a)
# Out:
# 33
# -13
# 230
# 0.43478260869565216
# 100000000000000000000000
# 41426511213649
# 41426511213649

# %%
a="hello"
b="world"
c=a+b
print(a+b)
print(c)
print("".join([a,b]))
# Out:
# helloworld
# helloworld
# helloworld

# %%
a="hello world"

print(a[2])   #print the single character of string
print(a[3])

print(len(a)) #length of string

print(a[1:4])   #print range in positive index
print(a[7:10])
print(a[-8:-5]) #negative index
# Out:
# l
# l
# 11
# ell
# orl
# lo

# %%
aname="omkar"
age=20
print("my name is {}".format(aname))
print("my age is {}".format(age))
print("my name is {}".format(aname) + "my age is {}".format(age))
# Out:
# my name is omkar
# my age is 20
# my name is omkarmy age is 20
