# %%
A=['parth','shreyash','Akash']
A[2]='Piyush'
print(A)
# Out:
# ['parth', 'shreyash', 'Piyush']

# %%
b=['Riya','Parth','Snehal']
c=['Ash','Anu','Sakshi']
b.append('Sanika')
print(b)
# Out:
# ['Riya', 'Parth', 'Snehal', 'Sanika']

# %%
c=['Run','Slow']
d=['Fast','Tall']
c.extend(['zero'])
print(c)
# Out:
# ['Run', 'Slow', 'zero']

# %%
c=['Rat','Cat']
d=['Dog','Rabbit']
c.insert(1,'Ran')
print(c)
# Out:
# ['Rat', 'Ran', 'Cat']

# %%
c=('shreya','Riya');
print(c)
# Out:
# ('shreya', 'Riya')

# %%
tuple = ('Itika', 'Arshia', 'Peter', 'Parker')
list(tuple).sort()
print(tuple)
print(len(tuple))
print(type(tuple))
# Out:
# ('Itika', 'Arshia', 'Peter', 'Parker')
# 4
# <class 'tuple'>
