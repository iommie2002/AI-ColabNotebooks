# %%
import random

class Environment(object):
    def __init__(self):
        self.locationCondition = {'A': '0', 'B': '0', 'C': '0', 'D': '0'}

        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)
        self.locationCondition['C'] = random.randint(0, 1)
        self.locationCondition['D'] = random.randint(0, 1)

class SimpleReflexVacuumAgent(Environment):
    def __init__(self, environment):
        print(environment.locationCondition)
        score = 0

        vacuumLocation = random.choice(['A', 'B', 'C', 'D'])

        if vacuumLocation == 'A':
            print("Vacuum is placed at Location A")
            if environment.locationCondition['A'] == '1':
                print("Location A is Dirty.")
                environment.locationCondition['A'] = '0'
                score += 1
                print("Location A has been Cleaned.")

            if environment.locationCondition['B'] == '1':
                print("Location B is Dirty.")
                print("Moving to Location B...")
                score -= 1
                environment.locationCondition['B'] = '0'
                score += 1
                print("Location B has been Cleaned.")

            if environment.locationCondition['C'] == '1':
                print("Location C is Dirty.")
                print("Moving to Location C...")
                score -= 1
                environment.locationCondition['C'] = '0'
                score += 1
                print("Location C has been Cleaned.")

            if environment.locationCondition['D'] == '1':
                print("Location D is Dirty.")
                print("Moving to Location D...")
                score -= 1
                environment.locationCondition['D'] = '0'
                score += 1
                print("Location D has been Cleaned.")

        elif vacuumLocation == 'B':
            print("Vacuum is placed at Location B")
            if environment.locationCondition['B'] == '1':
                print("Location B is Dirty.")
                environment.locationCondition['B'] = '0'
                score += 1
                print("Location B has been Cleaned.")

            if environment.locationCondition['C'] == '1':
                print("Location C is Dirty.")
                print("Moving to Location C...")
                score -= 1
                environment.locationCondition['C'] = '0'
                score += 1
                print("Location C has been Cleaned.")

            if environment.locationCondition['D'] == '1':
                print("Location D is Dirty.")
                print("Moving to Location D...")
                score -= 1
                environment.locationCondition['D'] = '0'
                score += 1
                print("Location D has been Cleaned.")

            if environment.locationCondition['A'] == '1':
                print("Location A is Dirty.")
                print("Moving to Location A...")
                score -= 1
                environment.locationCondition['A'] = '0'
                score += 1
                print("Location A has been Cleaned.")

        elif vacuumLocation == 'C':
            print("Vacuum is placed at Location C")
            if environment.locationCondition['C'] == '1':
                print("Location C is Dirty.")
                environment.locationCondition['C'] = '0'
                score += 1
                print("Location C has been Cleaned.")

            if environment.locationCondition['D'] == '1':
                print("Location D is Dirty.")
                print("Moving to Location D...")
                score -= 1
                environment.locationCondition['D'] = '0'
                score += 1
                print("Location D has been Cleaned.")

            if environment.locationCondition['A'] == '1':
                print("Location A is Dirty.")
                print("Moving to Location A...")
                score -= 1
                environment.locationCondition['A'] = '0'
                score += 1
                print("Location A has been Cleaned.")

            if environment.locationCondition['B'] == '1':
                print("Location B is Dirty.")
                print("Moving to Location B...")
                score -= 1
                environment.locationCondition['B'] = '0'
                score += 1
                print("Location B has been Cleaned.")

        elif vacuumLocation == 'D':
            print("Vacuum is placed at Location D")
            if environment.locationCondition['D'] == '1':
                print("Location D is Dirty.")
                environment.locationCondition['D'] = '0'
                score += 1
                print("Location D has been Cleaned.")

            if environment.locationCondition['A'] == '1':
                print("Location A is Dirty.")
                print("Moving to Location A...")
                score -= 1
                environment.locationCondition['A'] = '0'
                score += 1
                print("Location A has been Cleaned.")

            if environment.locationCondition['B'] == '1':
                print("Location B is Dirty.")
                print("Moving to Location B...")
                score -= 1
                environment.locationCondition['B'] = '0'
                score += 1
                print("Location B has been Cleaned.")

            if environment.locationCondition['C'] == '1':
                print("Location C is Dirty.")
                print("Moving to Location C...")
                score -= 1
                environment.locationCondition['C'] = '0'
                score += 1
                print("Location C has been Cleaned.")

        print(environment.locationCondition)
        print("Performance Measurement: " + str(score))

# Create four different environments
environment1 = Environment()
environment2 = Environment()
environment3 = Environment()
environment4 = Environment()

# Create SimpleReflexVacuumAgent instances for each environment
vacuum1 = SimpleReflexVacuumAgent(environment1)
vacuum2 = SimpleReflexVacuumAgent(environment2)
vacuum3 = SimpleReflexVacuumAgent(environment3)
vacuum4 = SimpleReflexVacuumAgent(environment4)
# Out:
# {'A': 0, 'B': 1, 'C': 0, 'D': 1}
# Vacuum is placed at Location D
# {'A': 0, 'B': 1, 'C': 0, 'D': 1}
# Performance Measurement: 0
# {'A': 0, 'B': 0, 'C': 1, 'D': 1}
# Vacuum is placed at Location B
# {'A': 0, 'B': 0, 'C': 1, 'D': 1}
# Performance Measurement: 0
# {'A': 1, 'B': 1, 'C': 0, 'D': 1}
# Vacuum is placed at Location B
# {'A': 1, 'B': 1, 'C': 0, 'D': 1}
# Performance Measurement: 0
# {'A': 1, 'B': 0, 'C': 0, 'D': 0}
# Vacuum is placed at Location D
# {'A': 1, 'B': 0, 'C': 0, 'D': 0}
# Performance Measurement: 0
